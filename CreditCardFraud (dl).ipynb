# %%
from matplotlib import pyplot as plt
import warnings
warnings.filterwarnings("ignore")
import seaborn as sns
import pandas as pd
import numpy as np
from imblearn.over_sampling import SMOTE #Synthetic Minority Over-sampling Technique
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model

# %%
df = pd.read_csv("C:/Users/itsme/Desktop/techybot/Credit Card Fruad Detection/Credit-card-fraud-detection/data/creditcard.csv")

# %%
df
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 0       0.462388  0.239599  0.098698  0.363787  ... -0.018307  0.277838
# 1      -0.082361 -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672
# 2       1.800499  0.791461  0.247676 -1.514654  ...  0.247998  0.771679
# 3       1.247203  0.237609  0.377436 -1.387024  ... -0.108300  0.005274
# 4       0.095921  0.592941 -0.270533  0.817739  ... -0.009431  0.798278
# ...          ...       ...       ...       ...  ...       ...       ...
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# 0      -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053  149.62
# 1       0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724    2.69
# 2       0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  378.66
# 3      -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458  123.50
# 4      -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153   69.99
# ...          ...       ...       ...       ...       ...       ...     ...
# 284802  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731    0.77
# 284803  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527   24.79
# 284804 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561   67.88
# 284805 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533   10.00
# 284806  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649  217.00
#
#         Class
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 284802      0
# 284803      0
# 284804      0
# 284805      0
# 284806      0
#
# [284807 rows x 31 columns]

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
fig, ax = plt.subplots(figsize=(20,10))
corr = df.corr()
sns.heatmap(corr, cmap="gray", ax=ax)
ax.set_title("Imbalanced Correlation Matrix", fontsize=14)
plt.show()

# %%
sns.countplot(x='Class',data=df)
# Out:
# <Axes: xlabel='Class', ylabel='count'>

# %%
sm = SMOTE(sampling_strategy='minority', random_state=7)
resampled_X, resampled_Y = sm.fit_resample(df.drop('Class', axis=1), df['Class'])
oversampled_df = pd.concat([pd.DataFrame(resampled_X), pd.DataFrame(resampled_Y)], axis=1)
oversampled_df.columns = df.columns
oversampled_df['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1    284315
# Name: count, dtype: int64

# %%
sns.countplot(x='Class', data=oversampled_df)
# Out:
# <Axes: xlabel='Class', ylabel='count'>

# %%
fig, ax = plt.subplots(figsize=(20,10))         
corr = oversampled_df.corr()
sns.heatmap(corr, cmap='YlGnBu', annot_kws={'size':30}, ax=ax)
ax.set_title("Imbalanced Correlation Matrix", fontsize=14)
plt.show()

# %%
sc = StandardScaler()
X = oversampled_df.iloc[:, 1:-1].values
y = oversampled_df.iloc[:, -1].values
y = y.reshape(-1, 1)
print(X.shape, y.shape)

X = sc.fit_transform(X)
print(X[0])
# Out:
# (568630, 29) (568630, 1)
# [ 0.20495125 -0.54573636  1.0045184  -0.30168224  0.31098779  0.6920209
#   0.55516986 -0.03644768  0.76125221  0.67923829 -0.92061643  0.57128753
#  -0.94634073  0.71704508  1.64724241  0.48636415  0.62706212  0.50679008
#   0.04977222  0.06379384 -0.14589103  0.24649907 -0.10441593  0.22564242
#   0.16596895 -0.48756152  0.05492719 -0.14984388  0.2455859 ]

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
adam = tf.keras.optimizers.Adam(learning_rate=0.0005)

# %%
x_features = X.shape[1]
y_features = y.shape[1]

# %%
i = Input(shape=(x_features,))

x = Dense(64, activation='relu')(i)
x = Dense(64, activation='relu')(x)
o = Dense(y_features, activation='sigmoid')(x)

model = Model(i,o)
model.compile(loss="binary_crossentropy", metrics=['accuracy'], optimizer=adam)
print(model.summary())
callback = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', min_delta=0, patience=10, verbose=0, mode='auto',
    baseline=None, restore_best_weights=True
)
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 29)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 64)                  │           1,920 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 64)                  │           4,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 6,145 (24.00 KB)
#  Trainable params: 6,145 (24.00 KB)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
r = model.fit(x_train, y_train, epochs=100, batch_size=512, verbose=1, validation_data=(x_test, y_test), callbacks=[callback])
# Out:
# Epoch 1/100
# 778/778 ━━━━━━━━━━━━━━━━━━━━ 16s 16ms/step - accuracy: 0.9082 - loss: 0.2211 - val_accuracy: 0.9829 - val_loss: 0.0485
# Epoch 2/100
# 778/778 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9865 - loss: 0.0395 - val_accuracy: 0.9932 - val_loss: 0.0237
# Epoch 3/100
# 778/778 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.9934 - loss: 0.0212 - val_accuracy: 0.9956 - val_loss: 0.0155
# Epoch 4/100
# 778/778 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9964 - loss: 0.0143 - val_accuracy: 0.9980 - val_loss: 0.0108
# Epoch 5/100
# 778/778 ━━━━━━━━━━━━━━━━━━━━ 15s 14ms/step - accuracy: 0.9979 - loss: 0.0098 - val_accuracy: 0.9981 - val_loss: 0.0082
# Epoch 6/100
# 778/778 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9985 - loss: 0.0074 - val_accuracy: 0.9987 - val_loss: 0.0065
# Epoch 7/100
# 778/778 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9987 - loss: 0.0063 - val_accuracy: 0.9985 - val_loss: 0.0061
# Epoch 8/100
# 778/778 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9990 - loss: 0.0049 - val_accuracy: 0.9991 - val_loss: 0.0047
# Epoch 9/100
# 778/778 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.9991 - loss: 0.0042 - val_accuracy: 0.9989 - val_loss: 0.0047
# Epoch 10/100
# 778/778 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9994 - loss: 0.0033 - val_accuracy: 0.9990 - val_loss: 0.0042
# Epoch 11/100
# 778/778 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9994 - loss: 0.0029 - val_accuracy: 0.9989 - val_loss: 0.0042
# Epoch 12/100
# 778/778 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9995 - loss: 0.0027 - val_accuracy: 0.9994 - val_loss: 0.0030
# Epoch 13/100
# 778/778 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9995 - loss: 0.0024 - val_accuracy: 0.9993 - val_loss: 0.0032
# Epoch 14/100
# 778/778 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9995 - loss: 0.0022 - val_accuracy: 0.9993 - val_loss: 0.0029
# Epoch 15/100
# 778/778 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9996 - loss: 0.0020 - val_accuracy: 0.9993 - val_loss: 0.0032
# Epoch 16/100
# 778/778 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9995 - loss: 0.0021 - val_accuracy: 0.9993 - val_loss: 0.0028
# Epoch 17/100
# 778/778 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9996 - loss: 0.0019 - val_accuracy: 0.9995 - val_loss: 0.0026
# Epoch 18/100
# 778/778 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9996 - loss: 0.0016 - val_accuracy: 0.9995 - val_loss: 0.0024
# Epoch 19/100
# 778/778 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9997 - loss: 0.0014 - val_accuracy: 0.9995 - val_loss: 0.0022
# Epoch 20/100
# 778/778 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9997 - loss: 0.0013 - val_accuracy: 0.9997 - val_loss: 0.0020
# Epoch 21/100
# 778/778 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9997 - loss: 0.0011 - val_accuracy: 0.9995 - val_loss: 0.0023
# Epoch 22/100
# 778/778 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9997 - loss: 0.0011 - val_accuracy: 0.9995 - val_loss: 0.0021
# Epoch 23/100
# 778/778 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9997 - loss: 0.0012 - val_accuracy: 0.9996 - val_loss: 0.0025
# Epoch 24/100
# 778/778 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.9996 - loss: 0.0013 - val_accuracy: 0.9997 - val_loss: 0.0020
# Epoch 25/100
# 778/778 ━━━━━━━━━━━━━━━━━━━━ 9s 7ms/step - accuracy: 0.9998 - loss: 9.5893e-04 - val_accuracy: 0.9993 - val_loss: 0.0025
# Epoch 26/100
# 778/778 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.9997 - loss: 0.0012 - val_accuracy: 0.9996 - val_loss: 0.0020
# Epoch 27/100
# 778/778 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9998 - loss: 0.0011 - val_accuracy: 0.9997 - val_loss: 0.0016
# Epoch 28/100
# 778/778 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.9998 - loss: 8.6758e-04 - val_accuracy: 0.9997 - val_loss: 0.0017
# Epoch 29/100
# 778/778 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9998 - loss: 7.9335e-04 - val_accuracy: 0.9997 - val_loss: 0.0018
# Epoch 30/100
# 778/778 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.9998 - loss: 8.1526e-04 - val_accuracy: 0.9998 - val_loss: 0.0016
# Epoch 31/100
# 778/778 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9998 - loss: 8.0202e-04 - val_accuracy: 0.9997 - val_loss: 0.0018
# Epoch 32/100
# 778/778 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9998 - loss: 8.8603e-04 - val_accuracy: 0.9995 - val_loss: 0.0022
# Epoch 33/100
# 778/778 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9997 - loss: 8.8387e-04 - val_accuracy: 0.9996 - val_loss: 0.0021
# Epoch 34/100
# 778/778 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9999 - loss: 6.9047e-04 - val_accuracy: 0.9996 - val_loss: 0.0017
# Epoch 35/100
# 778/778 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9998 - loss: 7.5549e-04 - val_accuracy: 0.9997 - val_loss: 0.0018
# Epoch 36/100
# 778/778 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9998 - loss: 6.6074e-04 - val_accuracy: 0.9997 - val_loss: 0.0016
# Epoch 37/100
# 778/778 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9998 - loss: 5.9526e-04 - val_accuracy: 0.9998 - val_loss: 0.0017

# %%
results = model.evaluate(x_test, y_test, batch_size=5, verbose=1)
print("Loss: %.2f" % results[0])
print("Acc: %.2f" % results[1])
# Out:
# 34118/34118 ━━━━━━━━━━━━━━━━━━━━ 122s 4ms/step - accuracy: 0.9997 - loss: 0.0018
# Loss: 0.00
# Acc: 1.00

# %%
print(r.history.keys())
plt.plot(r.history['loss'])
plt.plot(r.history['val_loss'])
plt.legend(['loss', 'val_loss'])
plt.show()

plt.plot(r.history['accuracy'])
plt.plot(r.history['val_accuracy'])
plt.legend(['accuracy', 'val_accuracy'])
plt.show()
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
y_pred = model.predict(x_test)
y_pred = np.round(y_pred, decimals=0).astype(int)
# Out:
# 5331/5331 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step

# %%
df_pred = pd.concat([pd.DataFrame(x_test), pd.DataFrame(y_test)], axis=1)
df_pred.columns = df.drop('Time', axis=1).columns
df_pred.rename(columns={"Class":"Old_class"}, inplace=True)
df_pred['New_class'] = y_pred
cm = pd.crosstab(df_pred["New_class"], df_pred['Old_class'])
true_pos = np.sum(np.diag(cm))
false_pos = cm[0][1]
false_neg = cm[1][0]
precision = true_pos / (true_pos + false_pos) * 100
recall = true_pos / (true_pos + false_neg) * 100
f1 = 2 * (precision * recall) / (precision + recall)
print("Precision: %.3f%%" % (precision))
print("Recall: %.3f%%" % (recall))
print("F1: %.3f%%" % (f1))
# Out:
# Precision: 99.972%
# Recall: 99.999%
# F1: 99.986%
